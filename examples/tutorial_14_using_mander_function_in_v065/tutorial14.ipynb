# %% [markdown]
# ### Example of the Mander function included in v0.65

# %% [markdown]
# #### This tutorial develops the following example:

# %%
from IPython.display import Image, display
display(Image(filename="section.png"))
# Out:
# max compression at:  [0.004714890009368263, 30.37275802061018]

# %%
import opseestools.utilidades as ut
e1,f1,e2,f2 = ut.mander(60,30,20,2,1.8,4,3,1.0,25,2*25/(4400*25**0.5),420,4,2)
print('max compression at: ', [e1,f1])
print('ultimate compression at: ', [e2,f2])
